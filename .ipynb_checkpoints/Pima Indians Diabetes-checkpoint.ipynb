# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
df = pd.read_csv("diabetes.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 795            2      112             66             22        0  25.0
# 796            3      113             44             13        0  22.4
# 797            3       96             56             34      115  24.7
# 798           13      126             90              0        0  43.4
# 799            4      129             86             20      270  35.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 795                     0.307   24        0
# 796                     0.140   22        0
# 797                     0.944   39        0
# 798                     0.583   42        1
# 799                     0.231   23        0

# %%
df.sample(6)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 515            3      163             70             18      105  31.6
# 795            2      112             66             22        0  25.0
# 731            8      120             86              0        0  28.4
# 304            3      150             76              0        0  21.0
# 222            7      119              0              0        0  25.2
# 307            0      137             68             14      148  24.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 515                     0.268   28        1
# 795                     0.307   24        0
# 731                     0.259   22        1
# 304                     0.207   37        0
# 222                     0.209   37        0
# 307                     0.143   21        0

# %%
# shape function gives number of rows and columns
df.shape
# Out:
# (800, 9)

# %%
# gives the datatypes of all columns
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# finding out if the dataset contains any null value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               800 non-null    int64
#  1   Glucose                   800 non-null    int64
#  2   BloodPressure             800 non-null    int64
#  3   SkinThickness             800 non-null    int64
#  4   Insulin                   800 non-null    int64
#  5   BMI                       800 non-null    float64
#  6   DiabetesPedigreeFunction  800 non-null    float64
#  7   Age                       800 non-null    int64
#  8   Outcome                   800 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 56.4 KB

# %%
# statistic summary of the dataset
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# count   800.000000  800.000000      800.00000     800.000000  800.00000
# mean      3.871250  120.506250       69.14500      20.435000   80.41875
# std       3.390286   31.940103       19.28734      15.917836  115.69225
# min       0.000000    0.000000        0.00000       0.000000    0.00000
# 25%       1.000000   99.000000       62.00000       0.000000    0.00000
# 50%       3.000000  117.000000       72.00000      23.000000   36.00000
# 75%       6.000000  139.000000       80.00000      32.000000  126.25000
# max      17.000000  199.000000      122.00000      99.000000  846.00000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  800.000000                800.000000  800.000000  800.000000
# mean    31.928750                  0.472711   33.147500    0.347500
# std      7.835614                  0.332059   11.678237    0.476474
# ...

# %% [markdown]
# Observation
#
# In the above table, the min value of columns "Glucose,BloodPressure,SkinThickness,Insulin,BMI" is zero(0), it is clear that this
# this values can't be zero so, I am going to replace zeroes with their mean values.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# drop the duplicates

# %%
# check the shape before dropping the duplicates
df.shape
# Out:
# (800, 9)

# %%
df = df.drop_duplicates()

# %%
# check the shape after dropping the duplicates
df.shape
# Out:
# (767, 9)

# %% [markdown]
# Check the number of zero values in the dataset

# %%
print('No.of zero values in Glucose is:',df[df['Glucose']==0].shape[0])
# Out:
# No.of zero values in Glucose is: 5

# %%
print('No.of zero values in BloodPressure is:',df[df['BloodPressure']==0].shape[0])
# Out:
# No.of zero values in BloodPressure is: 35

# %%
print('No.of zero values in SkinThickness is:',df[df['SkinThickness']==0].shape[0])
# Out:
# No.of zero values in SkinThickness is: 227

# %%
print('No.of zero values in Insulin is:',df[df['Insulin']==0].shape[0])
# Out:
# No.of zero values in Insulin is: 373

# %%
print('No.of zero values in BMI is:',df[df['BMI']==0].shape[0])
# Out:
# No.of zero values in BMI is: 11

# %% [markdown]
# Replace the zeroes with their column mean values

# %%
df['Glucose'] = df['Glucose'].replace(0,df['Glucose'].mean())
print('No.of zero values in Glucose is:',df[df['Glucose']==0].shape[0])
# Out:
# No.of zero values in Glucose is: 0

# %%
df['BloodPressure'] = df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['SkinThickness'] = df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['Insulin'] = df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI'] = df['BMI'].replace(0,df['BMI'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.848761  121.719237      72.257693      26.596714  118.761425
# std       3.370207   30.438211      12.123577       9.638762   93.109342
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000  100.000000      64.000000      20.522816   79.903520
# 50%       3.000000  117.000000      72.000000      23.000000   79.903520
# 75%       6.000000  140.500000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    32.453509                  0.472081   33.254237    0.349413
# std      6.879458                  0.331496   11.762079    0.477096
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Histogram - distribution of the data (skewness)

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# scatterplot - quickly understand the relationship between two variables

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(20,20));

# %% [markdown]
# pairplot - scatterplots between all variables

# %%
sns.pairplot(data=df, hue="Outcome")
plt.show()

# %% [markdown]
# # Analyzing Relationship between Variables

# %% [markdown]
# correlation analysis

# %%
import seaborn as sns
# get correlations of each matrix in the dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
# plot heatmap
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Split the DataFrame into x and y

# %%
target_name = 'Outcome'
# seperate object for target features
y = df[target_name]
# seperate object for input features
x = df.drop(target_name, axis=1)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 0            6    148.0           72.0      35.000000   79.90352  33.6
# 1            1     85.0           66.0      29.000000   79.90352  26.6
# 2            8    183.0           64.0      20.522816   79.90352  23.3
# 3            1     89.0           66.0      23.000000   94.00000  28.1
# 4            0    137.0           40.0      35.000000  168.00000  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # Apply feature scaling

# %%
# apply standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
SSX = scaler.transform(x)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

# %%
x_train.shape,y_train.shape
# Out:
# ((613, 8), (613,))

# %%
x_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# # Build the classification algorithms

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver="liblinear",multi_class="ovr")
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Naive-Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Support vector Machine (SVM)

# %%
from sklearn.svm import SVC
sv = SVC()
sv.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(criterion = "entropy")
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %% [markdown]
# # Making Prediction

# %% [markdown]
# Making prediction on test by using logistic Regression

# %%
lr_pred = lr.predict(x_test)

# %%
knn_pred = knn.predict(x_test)

# %%
nb_pred = nb.predict(x_test)

# %%
sv_pred = sv.predict(x_test)

# %%
dt_pred = dt.predict(x_test)

# %%
rf_pred = rf.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Train score and Test score

# %%
from sklearn.metrics import accuracy_score
# train score and test score of Logistic Regression
print("Train Accuracy of Logistic Regression", lr.score(x_train, y_train)*100)
print("Accuracy score of Logistic Regression",accuracy_score(y_test, lr_pred)*100)
# Out:
# Train Accuracy of Logistic Regression 77.32463295269169
# Accuracy (test) score of Logistic Regression 81.16883116883116
# Accuracy score of Logistic Regression 81.16883116883116

# %%
# train score and test score of KNN
print("Train Accuracy of KNN", knn.score(x_train, y_train)*100)
print("Accuracy score of KNN",accuracy_score(y_test, knn_pred)*100)
# Out:
# Train Accuracy of KNN 81.89233278955955
# Accuracy (test) score of KNN 75.32467532467533
# Accuracy score of KNN 75.32467532467533

# %%
# train score and test score of Naive-Bayes
print("Train Accuracy of Naive Bayes", nb.score(x_train, y_train)*100)
print("Accuracy score of Naive Bayes",accuracy_score(y_test, nb_pred)*100)
# Out:
# Train Accuracy of Naive Bayes 73.7357259380098
# Accuracy (test) score of Naive Bayes 78.57142857142857
# Accuracy score of Naive Bayes 78.57142857142857

# %%
# train score and test score of SVM
print("Train Accuracy of SVM", sv.score(x_train, y_train)*100)
print("Accuracy score of SVM",accuracy_score(y_test, sv_pred)*100)
# Out:
# Train Accuracy of SVM 82.05546492659053
# Accuracy (test) score of SVM 83.11688311688312
# Accuracy score of SVM 83.11688311688312

# %%
# train score and test score of Decision Tree
print("Train Accuracy of Decision Tree", dt.score(x_train, y_train)*100)
print("Accuracy score of Decision Tree",accuracy_score(y_test, dt_pred)*100)
# Out:
# Train Accuracy of Decision Tree 100.0
# Accuracy (test) score of Decision Tree 70.77922077922078
# Accuracy score of Decision Tree 70.77922077922078

# %%
# train score and test score of Random Forest
print("Train Accuracy of Random Forest", rf.score(x_train, y_train)*100)
print("Accuracy score of Random Forest",accuracy_score(y_test, rf_pred)*100)
# Out:
# Train Accuracy of Random Forest 100.0
# Accuracy (test) score of Random Forest 79.22077922077922
# Accuracy score of Random Forest 79.22077922077922

# %% [markdown]
# The accuracy (test score) of support vector machine(svm) is greater than all the other models
# Therefore, we are going to use svm

# %% [markdown]
# # Prediction

# %%
input_data = (5,78,48,0,0,33.7,0.654,25)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = sv.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.3418157  -1.43726467 -2.00217487 -2.76115007 -1.27633723  0.18130855
#    0.54914002 -0.70222478]]
# [0]
# The person is not diabetic
